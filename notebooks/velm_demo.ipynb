# %% [markdown]
# # VELM demo
# This notebook runs a small, reproducible VELM demo using the provided training script. It executes a short training run and shows pre/post metrics.

# %%
# Run a short VELM training/demo (CPU-friendly)
# !python3 ../src/train_velm_full.py --steps 20 --out ../outputs/demo_run --device cpu

# %%
# Display the pre/post accuracy summary written by the script
from pathlib import Path
p = Path('..') / 'outputs' / 'demo_run' / 'prepost.txt'
if p.exists():
    print(p.read_text())
else:
    print('No output found; check the previous cell for errors.')
